# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/stdcode2024/Session07 - 유형별로 실습하는 머신러닝/middleexam_김지수/codeset
# Out:
# /content/drive/MyDrive/Colab Notebooks/stdcode2024/Session07 - 유형별로 실습하는 머신러닝/middleexam_김지수/codeset

# %%
import pandas as pd
import pickle

# %%
with open("./mldtcore.dump", "rb") as fr:
  loadedDtModel = pickle.load(fr)

with open("./mlrfcore.dump", "rb") as fr:
  loadedRfModel = pickle.load(fr)

# %%
inputEngine = 1388
inputPower = 68.0
inputTransmission = 1  # 0(Automatic)과 1(Manual)만 있음

inputData = pd.DataFrame( [[inputEngine, inputPower, inputTransmission]] )
inputData
# Out:
#       0     1  2
# 0  1388  68.0  1

# %%
print( loadedDtModel.predict(inputData)[0] )
print( loadedRfModel.predict(inputData)[0] )
# Out:
# 1.8233333333333333
# 1.8201855841380843
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
